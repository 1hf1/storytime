# %%
from backend.agents.testerAgent.testerAgent import TesterAgent
# Out:
# /Users/hgf/miniconda3/envs/StoryTime/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from backend.evaluations.run_simulation_testing import run_simulation_testing
reports = run_simulation_testing(1)

# %%
reports
# Out:
# [{'accuracy_report': {'Metric': None, 'Report': ''},
#   'citations_report': {'Metric': None, 'Report': ''}}]

# %%
import json
from backend.stories.story_structure import StoryStructure
from backend.agents.testerAgent.testerAgent import TesterAgent

# Load the JSON data
with open("backend/stories/json_storage/A story about the Donald Trump Zohran Mamdani meeting-Donald Trump and Zohran Mamdani Meeting Story.json", 'r') as f:
    data = json.load(f)

# Create story and populate it
story = StoryStructure("test_story")
story.title = data['title']
story.research_document = data.get('research_document', '')
story.segments = data['segments']
#Drop image URIs
for seg in story.segments:
    seg['images'] = []
# Test it
tester = TesterAgent(story)
response = tester.test_story()

# %%
response
# Out:
# {'messages': [HumanMessage(content='Test the story and save the evaluation report. The story is:\n\n{\n  "title": "A Surprising Meeting: Donald Trump and Zohran Mamdani in the Oval Office",\n  "research_document": "\\n\\n--- Search Query: Donald Trump Zohran Mamdani meeting ---\\nTitle: President Trump Meets with Zohran Mamdani, Mayor-Elect, New York City\\nURL: https://www.youtube.com/watch?v=nDanzN1EUeE\\nSnippet: ## The White House\\n##### Nov 21, 2025 (0:30:46)\\nThe White House... for the mayor-elect. The President: Sure.\\n{ts:125} The Press: For you, you refer\\nto Mr. Mamdani as a \\"communist.\\" Can you describe\\nwhy you feel that way, and also, will you do anything\\nto stop him from arresting\\nPrime Minister Netanyahu if he visits New York?... You said, \\"I\'ll be\\nhis worst nightmare\\" and accused him\\nof having a fascist agenda. Are you planning to retract\\nany of these remarks\\n{ts:201} in order to improve\\nyour relationship? Zohran Mamdani: I think both\\nPre
# ...
